# %% [markdown]
# #  Kyra Friendly Therapist Chatbot
#
#
# built with OpenAI in 15 minutes!

# %% [markdown]
# ### Let's begin.,,
#
# Allow yourself 10 minutes a day to relax in a quiet place, sitting in comfortable reclining chair where you can chat.
#
# (Don't use the chat while driving or operating any machinery)
#
#
#
# ### Begin now
#
# Run the code below to get started:

# %%
import random 
import datetime

# %%
# Welcome message
print("Welcome to Kyra's chatbot!")

# Introduction
print("This  is chatbot is designed to chat with someone when you need it. Let's start with a few questions to get to know you better.")

# Ask questions
# Out:
# Welcome to Kyra's chatbot!
# This  is chatbot is designed to chat with someone when you need it. Let's start with a few questions to get to know you better.

# %%
#Part 1:Greeting

def greeting(name):
    print("Hi, I'm Kyra's therapist chatbot. What's your name?\n")
    name = input("My name is ")
    print("Nice to meet you, " + name + ".\n")
    
greeting("name")

# Part 2

age = input("What is your age? ")
fears = input("What are you afraid of? ")

# Provide some advice
print("Thanks for sharing; It's normal to be afraid of things. Let's start with some helpful advice.")

# Create list of advice
advice = ["Take a few deep breaths. Focus on letting go of your fear.", 
          "Focus on being present in the moment and connecting with your environment.", 
          "Remind yourself that your fear is only temporary and it will pass.", 
          "Focus on the positive things in your life and the goals that you want to achieve."]

# Print random advice from list
print(random.choice(advice))

# Ask for user input
user_input = input("Would you like to hear more advice or would you like to start the meditation? ")

# Check user input
if user_input == "advice":
    print(random.choice(advice))
elif user_input == "meditation":
    # Start meditation
    print("Let's begin the meditation. Close your eyes and take a few deep breaths.\n")
    print("Focus on the breath and let go of your fear.\n")
    print("Imagine a place that makes you feel safe and at peace.\n")
    print("Focus on that place and feel the sense of calm and peace.\n")
    print("Let go of your fear and focus on the positive feelings.\n")
    print("Take another deep breath and open your eyes when ready.\n")
    
    
## Part 3


# Ask user why they are feeling
def how_are_you():
    print("When was the first time when you felt this way?\n")
    feeling = input()
    print("I understand, it happened " + feeling + ".\n")
        
# Ask user what they would like to work on
def work_on():
    print("Would you like to start working on this problem now?\n")
    work = input()
    print("That sounds like a great idea. Let's get started.\n")

# Ask user what their goal is
def goal():
    print("Would you like to set this as your goal today?\n")
    goal = input()
    print("That's a great goal. Let's get started.\n")

# Ask user to relax
def relax():
    print("Now, let's take some time to relax. Take a few deep breaths, close your eyes and let go...\n")
    print("Focus on the breath and let go of your fear...\n")
    print("Imagine a place that makes you feel safe and at peace.\n")
    print("Focus on that place and feel the sense of calm and peace.\n")
    print("Let go of anything that bothers you and focus on the positive feelings.\n")
    print("Take another deep breath and open your eyes when ready.\n")

# Ask user how they are feeling
def how_are_you_2():
    print("How are you feeling now?\n")
    feeling = input()
    print("It's great that you're feeling " + feeling + ".\n")

# Ask user to visualize their goal
def visualize():
    print("Now, visualize yourself achieving your goal. What does it look like?\n")
    visualization = input()
    print("That's great. Keep that image in your mind.\n")

# Ask user to take action
def take_action():
    print("Now, take the first step towards achieving your goal. What will you do?\n")
    action = input()
    print("That's a great first step. I'm sure you'll be successful.\n")

# Ask user to reflect
def reflect():
    print("Take a few minutes to reflect on your progress. What have you accomplished so far?\n")
    reflection = input()
    print("That's great. Keep up the good work!\n")

# Ask user to set a date
def set_date():
    print("Now, set a date for when you want to achieve your goal. What date do you want to aim for? (use '%m/%d/%Y'format)\n")
    date = datetime.datetime.strptime(input(), "%m/%d/%Y")
    print("That's a great goal. I'm sure you can do it.\n")

# Ask user to create a plan
def create_plan():
    print("Now, create a plan for how you'll achieve your goal. What do you need to do?\n")
    plan = input()
    print("That's a great plan. I'm sure you can do it.\n")

# Ask user to take a break
def take_break():
    print("Take a break and come back to your goal later. What will you do?\n")
    break_activity = input()
    print("That sounds like a great idea. Enjoy your break!\n")

# Ask user to stay positive
def stay_positive():
    print("Remember to stay positive and focus on your goal. What will you do to stay positive?\n")
    positive_action = input()
    print("That's great. I'm sure that will help you stay focused.\n")

# Ask user to review their progress
def review_progress():
    print("Take some time to review your progress. What have you accomplished so far?\n")
    progress = input()
    print("That's great. Keep up the good work!\n")

# Ask user to reward themselves
def reward():
    print("Reward yourself for your progress. What will you do?\n")
    reward = input()
    print("That sounds like a great idea. Enjoy your reward!\n")

# Ask user to reflect on their progress
def reflect_2():
    print("Take a few minutes to reflect on your progress. What have you learned?\n")
    reflection = input()
    print("That's great. Keep up the good work!\n")

# Ask user for closing thoughts
def closing_thoughts():
    print("What are your closing thoughts?\n")
    thoughts = input()
    print("That's great. I'm glad we had this conversation.\n")

# Ask user for a random question
def random_question():
    questions = ["What is your favorite hobby?", "If you could travel anywhere, where would you go?", "What is something you're proud of?", "What is something you would like to learn?"]
    question = random.choice(questions)
    print(question + "\n")
    answer = input()
    print("That sounds like a great idea.\n")

# Ask user for parting words
def parting_words():
    print("Is there anything else you'd like to talk about?\n")
    words = input()
    print("That's great. I'm glad we had this conversation.\n")
    


how_are_you()
work_on()
goal()
relax()
how_are_you_2()
visualize()
take_action()
reflect()
set_date()
create_plan()
take_break()
stay_positive()
review_progress()
reward()
reflect_2()
closing_thoughts()
random_question()
parting_words()
# Out:
# Hi, I'm Kyra's therapist chatbot. What's your name?

# %% [markdown]
# #### Thanks for chatting - Have an awesome day!
